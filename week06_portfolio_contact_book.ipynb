# %% [markdown]
# # Week 6 Portfolio – Mini Contact Book
#
# This notebook builds a simple contact book using a Python dictionary.
# The name is the key and the phone number is the value.
#
# How I worked with AI:
# - I told it I am a beginner and asked for the simplest version first.
# - I asked it to explain each line so I could check I understood it.
# - I asked what could go wrong, and I tested the code myself in Colab.

# %%
# Step 1: Create a dictionary with 3 contacts
# The name is the key, and the phone number is the value
contacts = {
    "Alice": "0412 345 678",
    "Bob": "0400 111 222",
    "Charlie": "0433 999 888"
}

print(contacts)
# Out:
# {'Alice': '0412 345 678', 'Bob': '0400 111 222', 'Charlie': '0433 999 888'}

# %%
# Step 2: Add a new contact
contacts["Jiaying"] = "0455 123 456"

print(contacts)
# Out:
# {'Alice': '0412 345 678', 'Bob': '0400 111 222', 'Charlie': '0433 999 888', 'Jiaying': '0455 123 456'}

# %%
# Step 3: Update Bob's phone number
contacts["Bob"] = "0488 777 666"

print(contacts)
# Out:
# {'Alice': '0412 345 678', 'Bob': '0488 777 666', 'Charlie': '0433 999 888', 'Jiaying': '0455 123 456'}

# %%
# Step 4: Loop through the dictionary and print each contact
for name, phone in contacts.items():
    print(name + ", " + phone)
# Out:
# Alice, 0412 345 678
# Bob, 0488 777 666
# Charlie, 0433 999 888
# Jiaying, 0455 123 456

# %%
# Part B: Nested dictionary
# Each contact stores both a phone number and an email address
contacts_v2 = {
    "Alice":   {"phone": "0412 345 678", "email": "alice@example.com"},
    "Bob":     {"phone": "0488 777 666", "email": "bob@example.com"},
    "Charlie": {"phone": "0433 999 888", "email": "charlie@example.com"}
}

for name, details in contacts_v2.items():
    print(name + ", " + details["phone"] + ", " + details["email"])
# Out:
# Alice, 0412 345 678, alice@example.com
# Bob, 0488 777 666, bob@example.com
# Charlie, 0433 999 888, charlie@example.com

# %%
# Optional: ask for a name and print that person's details
name = input("Enter a name: ")

if name in contacts_v2:
    print(name + ", " + contacts_v2[name]["phone"] + ", " + contacts_v2[name]["email"])
else:
    print("Sorry, this name is not in the contact book.")

# %%
"""
AI Usage Note

Tool used: [doubao]

Prompt 1:
"I am a complete beginner learning Python. I need to create a dictionary
for a contact book with 3 contacts. The name is the key and the phone
number is the value. Then I need to add a new contact, change one phone
number, and loop through the dictionary to print each contact in the
format 'Name, phone number'. Please write the simplest possible code
with comments explaining everything."

What I did with the answer:
I typed the code into Google Colab one step at a time and ran each part.

What I changed and why:
I used my own names and phone numbers instead of the example ones.

What I learned:
A dictionary stores data as key and value pairs. .items() lets me loop
through the name and the phone number at the same time.
"""
